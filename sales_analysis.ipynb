# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data= pd.read_csv("saless.csv")
df=pd.DataFrame(data)

# %%
df.head(10)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  2019-01-01  2019-01-07  Standard Class
# 1              4919  CA-2019-160304  2019-01-02  2019-01-07  Standard Class
# 2              4920  CA-2019-160304  2019-01-02  2019-01-07  Standard Class
# 3              3074  CA-2019-125206  2019-01-03  2019-01-05     First Class
# 4              8604  US-2019-116365  2019-01-03  2019-01-08  Standard Class
# 5              8605  US-2019-116365  2019-01-03  2019-01-08  Standard Class
# 6              8606  US-2019-116365  2019-01-03  2019-01-08  Standard Class
# 7              9494  CA-2019-105207  2019-01-03  2019-01-08  Standard Class
# 8              9495  CA-2019-105207  2019-01-03  2019-01-08  Standard Class
# 9              2898  US-2019-164630  2019-01-04  2019-01-09  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
# 5    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
# 6    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
# 7    BO-11350      Bill Overfelt  Corporate  United States  Broken Arrow  ...
# 8    BO-11350      Bill Overfelt  Corporate  United States  Broken Arrow  ...
# 9    EB-13975         Erica Bern  Corporate  United States     Charlotte  ...
#
#                                         Product Name     Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...    73.940        1
# 1  Bush Westfield Collection Bookcases, Medium Ch...   173.940        3
# 2                                        GE 30522EE2   231.980        2
# 3  Recycled Steel Personal File for Hanging File ...   114.460        2
# 4                Imation Clip USB flash drive - 8 GB    30.080        2
# 5  WD My Passport Ultra 1TB Portable External Har...   165.600        3
# 6                      AT&T 17929 Lendline Telephone   180.960        5
# 7  Hon Practical Foundations 30 x 60 Training Tab...  1592.850        7
# 8                            Storex Dura Pro Binders    11.880        2
# 9           Hewlett Packard 310 Color Digital Copier   959.968        4
#
#      Profit Payment Mode avg profit  Profit status  Days Between Delivery  \
# 0   28.2668       Online        8.0    High Profit                      6
# 1   38.2668       Online        8.0    High Profit                      5
# 2   67.2742        Cards       83.5     Low Profit                      5
# 3   28.6150       Online       21.0    High Profit                      2
# 4   -5.2640       Online       83.5           Loss                      5
# 5   -6.2100       Online       83.5           Loss                      5
# 6   13.5720        Cards       83.5     Low Profit                      5
# 7  350.4270          COD        8.0    High Profit                      5
# 8    5.3460          COD       21.0     Low Profit                      5
# 9  119.9960       Online       83.5    High Profit                      5
#
#    Avg delivery date Delivery_remarks
# 0                5.0             Late
# 1                5.0             Fast
# 2                5.0             Fast
# 3                2.0             Fast
# 4                5.0             Fast
# 5                5.0             Fast
# 6                5.0             Fast
# 7                5.0             Fast
# 8                5.0             Fast
# 9                5.0             Fast
#
# [10 rows x 25 columns]

# %%
df.dtypes
# Out:
# Row ID+O6G3A1:R6           int64
# Order ID                  object
# Order Date                object
# Ship Date                 object
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country                   object
# City                      object
# State                     object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Profit                   float64
# Payment Mode              object
# avg profit               float64
# Profit status             object
# Days Between Delivery      int64
# Avg delivery date        float64
# Delivery_remarks          object
# dtype: object

# %%
df.describe()
# Out:
#        Row ID+O6G3A1:R6        Sales     Quantity       Profit   avg profit  \
# count       5901.000000  5901.000000  5901.000000  5901.000000  5901.000000
# mean        5022.422471   265.345589     3.781901    29.700408    29.718946
# std         2877.977184   474.260645     2.212917   259.589138    26.014845
# min            1.000000     0.836000     1.000000 -6599.978000     8.000000
# 25%         2486.000000    71.976000     2.000000     1.795500    21.000000
# 50%         5091.000000   128.648000     3.000000     8.502500    21.000000
# 75%         7456.000000   265.170000     5.000000    28.615000    21.000000
# max         9994.000000  9099.930000    14.000000  8399.976000    83.500000
#
#        Days Between Delivery  Avg delivery date
# count            5901.000000        5901.000000
# mean                3.926962           3.832232
# std                 1.792050           1.527816
# min                 0.000000           0.000000
# 25%                 3.000000           3.000000
# 50%                 4.000000           5.000000
# 75%                 5.000000           5.000000
# max                 8.000000           5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Row ID+O6G3A1:R6       5901 non-null   int64
#  1   Order ID               5901 non-null   object
#  2   Order Date             5901 non-null   object
#  3   Ship Date              5901 non-null   object
#  4   Ship Mode              5901 non-null   object
#  5   Customer ID            5901 non-null   object
#  6   Customer Name          5901 non-null   object
#  7   Segment                5901 non-null   object
#  8   Country                5901 non-null   object
#  9   City                   5901 non-null   object
#  10  State                  5901 non-null   object
#  11  Region                 5901 non-null   object
#  12  Product ID             5901 non-null   object
#  13  Category               5901 non-null   object
#  14  Sub-Category           5901 non-null   object
#  15  Product Name           5901 non-null   object
#  16  Sales                  5901 non-null   float64
#  17  Quantity               5901 non-null   int64
#  18  Profit                 5901 non-null   float64
#  19  Payment Mode           5901 non-null   object
#  20  avg profit             5901 non-null   float64
#  21  Profit status          5901 non-null   object
#  22  Days Between Delivery  5901 non-null   int64
#  23  Avg delivery date      5901 non-null   float64
#  24  Delivery_remarks       5901 non-null   object
# dtypes: float64(4), int64(3), object(18)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'region', 'product_id', 'category', 'sub_category', 'product_name',
#        'sales', 'quantity', 'profit', 'payment_mode', 'avg_profit',
#        'profit_status', 'days_between_delivery', 'avg_delivery_date',
#        'delivery_remark', 'year_month', 'Year'],
#       dtype='object')

# %%
df= df.rename(columns={'Order ID':"order_id", 'Order Date':"order_date", 'Ship Date':'ship_date', 'Ship Mode':'ship_mode',
        'Customer ID':'customer_id', 'Customer Name':'customer_name', 'Segment':'segment', 'Country':'country', 'City':'city', 'State':'state',
        'Region':'region', 'Product ID':'product_id', 'Category':'category', 'Sub-Category':'sub_category', 'Product Name':'product_name',
        'Sales':'sales', 'Quantity':'quantity', 'Profit':'profit', 'Payment Mode':'payment_mode', 'avg profit':'avg_profit',
        'Profit status':'profit_status', 'Days Between Delivery':'days_between_delivery', 'Avg delivery date':'avg_delivery_date',
        'Delivery_remarks':'delivery_remark'})

# %%
list=['ship_mode','category','sub_category','payment_mode','profit_status','delivery_remark']

# %%
df
# Out:
#       Row ID+O6G3A1:R6        order_id  order_date   ship_date  \
# 0                 4918  CA-2019-160304  2019-01-01  2019-01-07
# 1                 4919  CA-2019-160304  2019-01-02  2019-01-07
# 2                 4920  CA-2019-160304  2019-01-02  2019-01-07
# 3                 3074  CA-2019-125206  2019-01-03  2019-01-05
# 4                 8604  US-2019-116365  2019-01-03  2019-01-08
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  2020-12-30  2021-01-03
# 5897              1297  CA-2020-115427  2020-12-30  2021-01-03
# 5898              5092  CA-2020-156720  2020-12-30  2021-01-03
# 5899               909  CA-2020-143259  2020-12-30  2021-01-03
# 5900              5093  CA-2020-151450  2020-12-31  2021-01-04
#
#            ship_mode customer_id      customer_name    segment        country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3        First Class    LR-16915       Lena Radford   Consumer  United States
# 4     Standard Class    CA-12310  Christine Abelman  Corporate  United States
# ...              ...         ...                ...        ...            ...
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                city  ...                                       product_name  \
# 0      Gaithersburg  ...  Bush Westfield Collection Bookcases, Medium Ch...
# 1      Gaithersburg  ...  Bush Westfield Collection Bookcases, Medium Ch...
# 2      Gaithersburg  ...                                        GE 30522EE2
# 3       Los Angeles  ...  Recycled Steel Personal File for Hanging File ...
# 4       San Antonio  ...                Imation Clip USB flash drive - 8 GB
# ...             ...  ...                                                ...
# 5896  New York City  ...  Bush Westfield Collection Bookcases, Fully Ass...
# 5897      Fairfield  ...    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# 5898       Loveland  ...                                Bagged Rubber Bands
# 5899  New York City  ...               Wilson Jones Legal Size Ring Binders
# 5900       Loveland  ...                                Bagged Rubber Bands
#
#          sales quantity   profit payment_mode avg_profit  profit_status  \
# 0       73.940        1  28.2668       Online        8.0    High Profit
# 1      173.940        3  38.2668       Online        8.0    High Profit
# 2      231.980        2  67.2742        Cards       83.5     Low Profit
# 3      114.460        2  28.6150       Online       21.0    High Profit
# 4       30.080        2  -5.2640       Online       83.5           Loss
# ...        ...      ...      ...          ...        ...            ...
# 5896   213.136        4  12.1176          COD        8.0    High Profit
# 5897   295.904        2   4.5188       Online       21.0     Low Profit
# 5898   388.024        3  -0.6048       Online       21.0           Loss
# 5899   462.776        3  19.7910          COD       21.0     Low Profit
# 5900  2975.510        3  -0.6048          COD       21.0           Loss
#
#       days_between_delivery  avg_delivery_date delivery_remark
# 0                         6                5.0            Late
# 1                         5                5.0            Fast
# 2                         5                5.0            Fast
# 3                         2                2.0            Fast
# 4                         5                5.0            Fast
# ...                     ...                ...             ...
# 5896                      4                5.0            Fast
# 5897                      4                5.0            Fast
# 5898                      4                5.0            Fast
# 5899                      4                5.0            Fast
# 5900                      4                5.0            Fast
#
# [5901 rows x 25 columns]

# %%
list=['order_date', 'ship_date' ]
df[list]= df[list].apply(pd.to_datetime , errors='coerce')

# %%
list=['ship_mode','category','sub_category','payment_mode','profit_status','delivery_remark']
df[list]= df[list].astype('category')

# %%
df['year_month']= df['order_date'].dt.to_period("M").astype(str)

# %% [markdown]
# -------------------------------------------------- analysis-------------------------------------------------------------------------------------------------

# %%
df.head(2)
# Out:
#    Row ID+O6G3A1:R6        order_id order_date  ship_date       ship_mode  \
# 0              4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1              4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
#
#   customer_id  customer_name    segment        country          city  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     sales quantity   profit payment_mode avg_profit profit_status  \
# 0   73.94        1  28.2668       Online        8.0   High Profit
# 1  173.94        3  38.2668       Online        8.0   High Profit
#
#    days_between_delivery  avg_delivery_date  delivery_remark year_month
# 0                      6                5.0             Late    2019-01
# 1                      5                5.0             Fast    2019-01
#
# [2 rows x 26 columns]

# %% [markdown]
# sales over time  and sales count over that period

# %%
group=df.groupby('year_month').agg(total_sales=('sales','sum') , total_no_of_sales=('order_id','count'))

# %%
group["growth_rate"] = group["total_sales"].pct_change() * 100
group
# Out:
#             total_sales  total_no_of_sales  growth_rate
# year_month
# 2019-01      18616.4310                 90          NaN
# 2019-02      19978.8150                 83     7.318180
# 2019-03      51715.8750                163   158.853566
# 2019-04      38750.0390                170   -25.071288
# 2019-05      50987.7280                225    31.581101
# 2019-06      40344.5340                199   -20.874031
# 2019-07      39261.9630                201    -2.683315
# 2019-08      31115.3743                176   -20.749316
# 2019-09      73410.0249                363   135.928465
# 2019-10      42687.7450                196   -41.850251
# 2019-11      79411.9658                370    86.029892
# 2019-12      78399.0430                352    -1.275529
# 2020-01      54763.3740                155   -30.147905
# 2020-02      52068.1334                107    -4.921612
# 2020-03      64229.3528                238    23.356358
# 2020-04      50807.5361                203   -20.896702
# 2020-05      66750.1102                242    31.378365
# 2020-06      69242.7257                245     3.734249
# 2020-07      60077.4160                226   -13.236495
# 2020-08      77338.8880                218    28.732048
# 2020-09     119803.6520                459    54.907389
# 2020-10      88896.9232                298   -25.797819
# 2020-11     130960.8250                459    47.317613
# 2020-12     166185.8488                463    26.897375

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
df.groupby('year_month')[['sales','profit']].sum().plot(kind='line', marker='o')
plt.title("Sales and Profit Over Time")
plt.ylabel("Amount")
plt.show()

# 2. Sales by Category
plt.figure(figsize=(10,6))
sns.barplot(x="category", y="sales", data=df, estimator=sum, ci=None)
plt.title("Total Sales by Category")
plt.show()

# 3. Profit Distribution
plt.figure(figsize=(10,6))
sns.histplot(df['profit'], bins=50, kde=True)
plt.title("Profit Distribution")
plt.show()

# 4. Sales vs Profit Scatter
plt.figure(figsize=(10,6))
sns.scatterplot(x="sales", y="profit", hue="segment", data=df, alpha=0.7)
plt.title("Sales vs Profit by Segment")
plt.show()

# 5. Orders by Segment
plt.figure(figsize=(8,6))
sns.countplot(x="segment", data=df)
plt.title("Number of Orders by Segment")
plt.show()

# 6. Delivery Days by Ship Mode
plt.figure(figsize=(10,6))
sns.boxplot(x="ship_mode", y="days_between_delivery", data=df)
plt.title("Delivery Days by Ship Mode")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\2189642296.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="category", y="sales", data=df, estimator=sum, ci=None)

# %%
sns.set_theme(style="whitegrid")

# Convert year_month to datetime
df['year_month'] = pd.to_datetime(df['year_month'], format='%Y-%m')

# Aggregate monthly sales
monthly_sales = df.groupby('year_month')['sales'].sum().reset_index()

# Calculate monthly growth rate (percentage)
monthly_sales['growth_rate'] = monthly_sales['sales'].pct_change() * 100

# --- Monthly Sales Trend with Growth Rate ---
plt.figure(figsize=(14, 6))
sns.lineplot(data=monthly_sales, x='year_month', y='sales', marker='o', linewidth=2, color="#4C72B0")

# Add growth rate annotations
for i in range(1, len(monthly_sales)):
    plt.text(
        x=monthly_sales['year_month'][i],
        y=monthly_sales['sales'][i] + (monthly_sales['sales'].max() * 0.02),  # shift a bit upward
        s=f"{monthly_sales['growth_rate'][i]:.1f}%",
        ha='center',
        fontsize=9,
        color='darkgreen' if monthly_sales['growth_rate'][i] > 0 else 'red'
    )

# Styling
plt.title("📈 Monthly Sales Trend with Growth Rate", fontsize=14, weight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# --- Number of Sales per Month ---
plt.figure(figsize=(14, 6))
sns.histplot(
    data=df,
    x='year_month',
    bins=len(df['year_month'].unique()),
    discrete=True,
    color="#04651B",
    edgecolor="black"
)

# Styling
plt.title("🛒 Number of Sales Over Time", fontsize=14, weight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Transactions", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\483809325.py:33: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\483809325.py:53: UserWarning: Glyph 128722 (\N{SHOPPING TROLLEY}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128722 (\N{SHOPPING TROLLEY}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
group=df.groupby('category').agg(tsales=('sales','sum'), total_order=('order_id','count'),tprofit=('profit','sum'))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\97975001.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group=df.groupby('category').agg(tsales=('sales','sum'), total_order=('order_id','count'),tprofit=('profit','sum'))

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 6))  # 1 row, 3 columns

# Pie chart - Total Sales
axes[0].pie(group['tsales'], labels=group.index, autopct='%1.1f%%', startangle=90)
axes[0].set_title("Sales Distribution")

# Pie chart - Total Profit
axes[1].pie(group['tprofit'], labels=group.index, autopct='%1.1f%%', startangle=90)
axes[1].set_title("Profit Distribution")

# Pie chart - Total Orders
axes[2].pie(group['total_order'], labels=group.index, autopct='%1.1f%%', startangle=90)
axes[2].set_title("Orders Distribution")

plt.suptitle("Category-wise Distribution Overview", fontsize=16)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# --- Sales by Category ---
sns.barplot(
    data=df, x='category', y='sales', estimator=np.sum, hue='payment_mode',
    ax=axes[0, 0]
)
axes[0, 0].set_title("Total Sales by Category & Payment Mode")
axes[0, 0].set_xlabel("Category")
axes[0, 0].set_ylabel("Total Sales")

# --- Profit by Category ---
sns.barplot(
    data=df, x='category', y='profit', estimator=np.sum, hue='payment_mode',
    ax=axes[0, 1]
)
axes[0, 1].set_title("Total Profit by Category & Payment Mode")
axes[0, 1].set_xlabel("Category")
axes[0, 1].set_ylabel("Total Profit")

# --- Quantity by Category ---
sns.barplot(
    data=df, x='category', y='quantity', estimator=np.sum, hue='payment_mode',
    ax=axes[1, 0]
)
axes[1, 0].set_title("Total Quantity by Category & Payment Mode")
axes[1, 0].set_xlabel("Category")
axes[1, 0].set_ylabel("Total Quantity")

# Remove empty subplot (bottom-right)
axes[1, 1].axis("off")

# Adjust layout
plt.suptitle("Category-wise Analysis by Payment Mode", fontsize=18, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.96])  # leave space for main title

# Move legend outside (so it doesn’t clutter)
handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.1, 0.95))

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# --- Sales by Category ---
sns.barplot(
    data=df, x='segment', y='sales', estimator=np.sum, hue='payment_mode',
    ax=axes[0, 0]
)
axes[0, 0].set_title("Total Sales by Customer  segment & Payment Mode")
axes[0, 0].set_xlabel("client segment")
axes[0, 0].set_ylabel("Total Sales")

# --- Profit by Category ---
sns.barplot(
    data=df, x='segment', y='profit', estimator=np.sum, hue='payment_mode',
    ax=axes[0, 1]
)
axes[0, 1].set_title("Total Profit by Category & Payment Mode")
axes[0, 1].set_xlabel("Client segment")
axes[0, 1].set_ylabel("Total Profit")

# --- Quantity by Category ---
sns.barplot(
    data=df, x='segment', y='quantity', estimator=np.sum, hue='payment_mode',
    ax=axes[1, 0]
)
axes[1, 0].set_title("Total Quantity by Category & Payment Mode")
axes[1, 0].set_xlabel("Client Segment")
axes[1, 0].set_ylabel("Total Quantity")

# Remove empty subplot (bottom-right)
axes[1, 1].axis("off")

# Adjust layout
plt.suptitle("Category-wise Analysis by Payment Mode", fontsize=18, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.96])  # leave space for main title

# Move legend outside (so it doesn’t clutter)
handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right", bbox_to_anchor=(1.1, 0.95))

plt.show()

# %%
df.head(5)
# Out:
#    Row ID+O6G3A1:R6        order_id order_date  ship_date       ship_mode  \
# 0              4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1              4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 2              4920  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 3              3074  CA-2019-125206 2019-01-03 2019-01-05     First Class
# 4              8604  US-2019-116365 2019-01-03 2019-01-08  Standard Class
#
#   customer_id      customer_name    segment        country          city  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
#     sales quantity   profit payment_mode avg_profit profit_status  \
# 0   73.94        1  28.2668       Online        8.0   High Profit
# 1  173.94        3  38.2668       Online        8.0   High Profit
# 2  231.98        2  67.2742        Cards       83.5    Low Profit
# 3  114.46        2  28.6150       Online       21.0   High Profit
# 4   30.08        2  -5.2640       Online       83.5          Loss
#
#    days_between_delivery  avg_delivery_date  delivery_remark year_month
# 0                      6                5.0             Late 2019-01-01
# 1                      5                5.0             Fast 2019-01-01
# 2                      5                5.0             Fast 2019-01-01
# 3                      2                2.0             Fast 2019-01-01
# 4                      5                5.0             Fast 2019-01-01
#
# [5 rows x 26 columns]

# %%
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# --- Sales by Ship Mode ---
sns.barplot(
    data=df, x='ship_mode', y='sales', estimator=np.sum, ax=axes[0, 0]
)
axes[0, 0].set_title("Total Sales by Ship Mode")
axes[0, 0].set_xlabel("Ship Mode")
axes[0, 0].set_ylabel("Total Sales")

# --- Profit by Ship Mode ---
sns.barplot(
    data=df, x='ship_mode', y='profit', estimator=np.sum, ax=axes[0, 1]
)
axes[0, 1].set_title("Total Profit by Ship Mode")
axes[0, 1].set_xlabel("Ship Mode")
axes[0, 1].set_ylabel("Total Profit")

# --- Quantity by Ship Mode ---
sns.barplot(
    data=df, x='ship_mode', y='quantity', estimator=np.sum, ax=axes[1, 0]
)
axes[1, 0].set_title("Total Quantity by Ship Mode")
axes[1, 0].set_xlabel("Ship Mode")
axes[1, 0].set_ylabel("Total Quantity")

# Remove empty subplot (bottom-right)
axes[1, 1].axis("off")

# Adjust layout
plt.suptitle("Ship Mode-wise Analysis", fontsize=18, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.96])  # leave space for main title

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# --- Sales by Region & Category ---
sns.barplot(
    data=df, x='region', y='sales', estimator=np.sum, hue='category', ax=axes[0, 0]
)
axes[0, 0].set_title("Total Sales by Region & Category", fontsize=12, weight="bold")
axes[0, 0].set_xlabel("Region")
axes[0, 0].set_ylabel("Total Sales")

# --- Sales by Region & Payment Mode ---
sns.barplot(
    data=df, x='region', y='sales', estimator=np.sum, hue='payment_mode', ax=axes[0, 1]
)
axes[0, 1].set_title("Total Sales by Region & Payment Mode", fontsize=12, weight="bold")
axes[0, 1].set_xlabel("Region")
axes[0, 1].set_ylabel("Total Sales")

# --- Sales by Region & Segment ---
sns.barplot(
    data=df, x='region', y='sales', estimator=np.sum, hue='segment', ax=axes[1, 0]
)
axes[1, 0].set_title("Total Sales by Region & Segment", fontsize=12, weight="bold")
axes[1, 0].set_xlabel("Region")
axes[1, 0].set_ylabel("Total Sales")

# --- Sales by Region & Ship Mode ---
sns.barplot(
    data=df, x='region', y='sales', estimator=np.sum, hue='ship_mode', ax=axes[1, 1]
)
axes[1, 1].set_title("Total Sales by Region & Ship Mode", fontsize=12, weight="bold")
axes[1, 1].set_xlabel("Region")
axes[1, 1].set_ylabel("Total Sales")

# Adjust layout
plt.suptitle("📊 Region-wise Sales Analysis by Different Factors", fontsize=16, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for main title
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\2165282934.py:39: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for main title
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# --- Sales by Region & Category ---
sns.barplot(
    data=df, x='region', y='quantity', estimator=np.sum, hue='category', ax=axes[0, 0]
)
axes[0, 0].set_title("Total Quantity sold by Region & Category", fontsize=12, weight="bold")
axes[0, 0].set_xlabel("Region")
axes[0, 0].set_ylabel("Total Sales")

# --- Sales by Region & Payment Mode ---
sns.barplot(
    data=df, x='region', y='quantity', estimator=np.sum, hue='payment_mode', ax=axes[0, 1]
)
axes[0, 1].set_title("Total Quantity sold by Region & Payment Mode", fontsize=12, weight="bold")
axes[0, 1].set_xlabel("Region")
axes[0, 1].set_ylabel("Total Sales")

# --- Sales by Region & Segment ---
sns.barplot(
    data=df, x='region', y='quantity', estimator=np.sum, hue='segment', ax=axes[1, 0]
)
axes[1, 0].set_title("Total Quantity sold by Region & Segment", fontsize=12, weight="bold")
axes[1, 0].set_xlabel("Region")
axes[1, 0].set_ylabel("Total Sales")

# --- Sales by Region & Ship Mode ---
sns.barplot(
    data=df, x='region', y='quantity', estimator=np.sum, hue='ship_mode', ax=axes[1, 1]
)
axes[1, 1].set_title("Total Quantity sold by Region & Ship Mode", fontsize=12, weight="bold")
axes[1, 1].set_xlabel("Region")
axes[1, 1].set_ylabel("Total Sales")

# Adjust layout
plt.suptitle("📊 Region-wise Quantity Analysis by Different Factors", fontsize=16, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for main title
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\1901671866.py:39: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for main title
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(3, 1, figsize=(16, 18))  # 3 rows, 1 column

# --- Sales by Sub-Category & Payment Mode ---
sns.barplot(
    data=df, x='sub_category', y='sales', estimator=np.sum, hue='payment_mode', ax=axes[0]
)
axes[0].set_title("Total Sales by Sub-Category & Payment Mode", fontsize=12, weight="bold")
axes[0].set_xlabel("Sub-Category")
axes[0].set_ylabel("Total Sales")
axes[0].tick_params(axis='x', rotation=45)

# --- Sales by Sub-Category & Segment ---
sns.barplot(
    data=df, x='sub_category', y='sales', estimator=np.sum, hue='segment', ax=axes[1]
)
axes[1].set_title("Total Sales by Sub-Category & Segment", fontsize=12, weight="bold")
axes[1].set_xlabel("Sub-Category")
axes[1].set_ylabel("Total Sales")
axes[1].tick_params(axis='x', rotation=45)

# --- Sales by Sub-Category & Ship Mode ---
sns.barplot(
    data=df, x='sub_category', y='sales', estimator=np.sum, hue='ship_mode', ax=axes[2]
)
axes[2].set_title("Total Sales by Sub-Category & Ship Mode", fontsize=12, weight="bold")
axes[2].set_xlabel("Sub-Category")
axes[2].set_ylabel("Total Sales")
axes[2].tick_params(axis='x', rotation=45)

# Adjust layout
plt.suptitle("📊 Sub-Category-wise Sales Analysis by Different Factors", fontsize=16, fontweight="bold")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16336\1657913537.py:38: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['Year']= df['order_date'].dt.year

# %%
plt.subplot(2,2,1)
sns.countplot(data=df , x='profit_status' , hue='delivery_remark')
plt.subplot(2,2,2)
sns.countplot(data=df , x='region', hue='delivery_remark')
plt.subplot(2,2,3)
sns.countplot( data=df , x='Year' , hue='delivery_remark')
plt.subplot(2,2,4)
sns.countplot( data=df , x='segment' , hue='delivery_remark')
# Out:
# <Axes: xlabel='segment', ylabel='count'>

# %%
plt.subplot(2,2,1)
sns.barplot(data=df , x='Year' , y='sales' , estimator=np.sum , hue='category')
plt.subplot(2,2,2)
sns.barplot(data=df , x='Year', y='profit',estimator= np.sum ,hue='category')
plt.subplot(2,2,3)
sns.barplot( data=df , x='Year' , y='quantity',estimator=np.sum ,hue='category')
plt.subplot(2,2,4)
sns.countplot( data=df , x='Year' ,hue='customer_segment')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 8
#       6 sns.barplot( data=df , x='Year' , y='quantity',estimator=np.sum ,hue='category')
#       7 plt.subplot(2,2,4)
# ----> 8 sns.countplot( data=df , x='Year' ,hue='customer_segment')
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)     64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)     76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `customer_segment` for `hue`. An entry with this name does not appear in `data`.
